# %% [markdown]
# **Using Spark dataframes**

# %% [markdown]
# **Method 1- Using PySpark dataframes**

# %%
df = spark.read.format("csv").option("header","true").load("abfss://46df290c-a4bf-4f21-ae5b-b2a4f313e3d8@onelake.dfs.fabric.microsoft.com/00c15e94-6196-49d0-a58b-ead20e68f78e/Files/People-WWI-New.csv")
df.write.format("delta").mode("overwrite").saveAsTable('People')
# Out:
# StatementMeta(, 529979c4-6116-4b82-9196-71a019a1971f, 18, Finished, Available)

# %% [markdown]
# **Method 2- Using PySpark dataframes**

# %%
df.write.format("delta").mode("overwrite").save('Tables/People2')
# Out:
# StatementMeta(, 529979c4-6116-4b82-9196-71a019a1971f, 16, Finished, Available)

# %% [markdown]
# **Method 3- Using SQL DDL**

# %%
# %%sql
# CREATE OR REPLACE TABLE Contacts
# (PersonID INTEGER,
# EmailAddress STRING)
# USING DELTA
# Out:
# StatementMeta(, fd83c4fe-ac97-4962-8192-b52524ddcf55, 20, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# **Method 4- Using SQL CTAS**

# %%
# %%sql
# CREATE OR REPLACE TABLE Contacts_ctas
# USING DELTA
# AS
# SELECT PersonID,EmailAddress FROM People
# Out:
# StatementMeta(, fd83c4fe-ac97-4962-8192-b52524ddcf55, 27, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# **Auto discovery of tables**
# 1. Download folder for contacts_ctas
# 2. Drop table contacts_ctas
# 3. Upload folder for contacts_ctas

# %% [markdown]
# **Managed tables**

# %%
# %%sql
# DROP TABLE contacts

# %% [markdown]
# **Unmanaged (external) tables**

# %%
# %%sql
# CREATE OR REPLACE TABLE Contacts_ext
# (PersonID INTEGER,
# EmailAddress STRING)
# USING DELTA
# LOCATION "Files/DeltaTables/Contacts_ext"
# Out:
# StatementMeta(, fd83c4fe-ac97-4962-8192-b52524ddcf55, 32, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# INSERT INTO Contacts_ext
# SELECT PersonID,EmailAddress FROM People
# Out:
# StatementMeta(, fd83c4fe-ac97-4962-8192-b52524ddcf55, 30, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# DROP TABLE Contacts_ext
# Out:
# StatementMeta(, fd83c4fe-ac97-4962-8192-b52524ddcf55, 31, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# SELECT * FROM Contacts_ext
# Out:
# StatementMeta(, fd83c4fe-ac97-4962-8192-b52524ddcf55, 33, Finished, Available)
# <Spark SQL result set with 1000 rows and 2 fields>

# %% [markdown]
# External table
