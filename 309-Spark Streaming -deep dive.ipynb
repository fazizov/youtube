# %% [markdown]
# **Reading from Event Hub and persisting in the Bronze table**

# %%
# !pip install azure-eventhub
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 7, Finished, Available)
# Collecting azure-eventhub
#   Downloading azure_eventhub-5.11.5-py3-none-any.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: azure-core<2.0.0,>=1.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from azure-eventhub) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from azure-eventhub) (4.5.0)
# Requirement already satisfied: requests>=2.18.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.14.0->azure-eventhub) (2.28.2)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.14.0->azure-eventhub) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-eventhub) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-eventhub) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-eventhub) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-eventhub) (1.26.14)
# Installing collected packages: azure-eventhub
# Successfully installed azure-eventhub-5.11.5

# %%
connectionString = "Endpoint=;EntityPath="
ehConf = {}
ehConf['eventhubs.connectionString'] = sc._jvm.org.apache.spark.eventhubs.EventHubsUtils.encrypt(connectionString)
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 6, Finished, Available)

# %%
from azure.eventhub import EventHubConsumerClient
from notebookutils import mssparkutils
import pyspark.sql.functions as f
from pyspark.sql.types import *
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 8, Finished, Available)

# %%
tableName='CarTraffic_Raw'
tablePath='Tables/'+tableName
checkpointFolder="Files/Checkpoints/"+tableName

dfRaw=spark.readStream.format("eventhubs").options(**ehConf).load()

strmHandle =dfRaw.withColumn("bodyAsString", f.col("body").cast("string"))\
  .writeStream\
  .queryName('BrzTrafficStream')\
  .format("delta")\
  .option("checkpointLocation", checkpointFolder)\
  .outputMode("append")\
  .option("path", tablePath).start()
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 60, Finished, Available)

# %% [markdown]
# **Read stream's status and last progress**

# %%
print (f'Is the stream active?:{strmHandle.isActive}',f', Stream status:{strmHandle.status}')
strmHandle.recentProgress
# strmHandle.stop()
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 62, Finished, Available)
# Is the stream active?:True , Stream status:{'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# [{'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:48:53.668Z',
#   'batchId': 12,
#   'numInputRows': 6,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 1.5155342258145996,
#   'durationMs': {'addBatch': 2723,
#    'getBatch': 6,
#    'getOffset': 9,
#    'queryPlanning': 5,
#    'triggerExecution': 3959,
#    'walCommit': 494},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60448}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 6,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 1.5155342258145996}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:49:07.549Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 1994, 'triggerExecution': 1994},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:49:19.361Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 2010, 'triggerExecution': 2011},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:49:31.368Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 9, 'triggerExecution': 9},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:49:40.835Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 1920, 'triggerExecution': 1920},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:49:52.747Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 9, 'triggerExecution': 9},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:50:02.766Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 9, 'triggerExecution': 9},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:50:12.771Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 9, 'triggerExecution': 9},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:50:22.132Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 1951, 'triggerExecution': 1951},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:50:33.833Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 1922, 'triggerExecution': 1922},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:50:45.752Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 9, 'triggerExecution': 9},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:50:55.306Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 2000, 'triggerExecution': 2000},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:07.302Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 9, 'triggerExecution': 9},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:17.308Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 9, 'triggerExecution': 9},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:26.642Z',
#   'batchId': 13,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'getOffset': 1967, 'triggerExecution': 1967},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 60454}},
#     'latestOffset': {'fa-eh': {'0': 60454}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:30.547Z',
#   'batchId': 13,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 52631.57894736842,
#   'processedRowsPerSecond': 209.77554017201592,
#   'durationMs': {'addBatch': 2275,
#    'getBatch': 6,
#    'getOffset': 1938,
#    'queryPlanning': 4,
#    'triggerExecution': 4767,
#    'walCommit': 314},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 60454}},
#     'endOffset': {'fa-eh': {'0': 61454}},
#     'latestOffset': {'fa-eh': {'0': 61454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 52631.57894736842,
#     'processedRowsPerSecond': 209.77554017201592}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:35.315Z',
#   'batchId': 14,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 209.73154362416108,
#   'processedRowsPerSecond': 489.2367906066536,
#   'durationMs': {'addBatch': 1562,
#    'getBatch': 6,
#    'getOffset': 9,
#    'queryPlanning': 3,
#    'triggerExecution': 2044,
#    'walCommit': 218},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 61454}},
#     'endOffset': {'fa-eh': {'0': 62454}},
#     'latestOffset': {'fa-eh': {'0': 62454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 209.73154362416108,
#     'processedRowsPerSecond': 489.2367906066536}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:37.360Z',
#   'batchId': 15,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 488.99755501222495,
#   'processedRowsPerSecond': 515.9958720330237,
#   'durationMs': {'addBatch': 1496,
#    'getBatch': 6,
#    'getOffset': 9,
#    'queryPlanning': 5,
#    'triggerExecution': 1938,
#    'walCommit': 204},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 62454}},
#     'endOffset': {'fa-eh': {'0': 63454}},
#     'latestOffset': {'fa-eh': {'0': 63454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 488.99755501222495,
#     'processedRowsPerSecond': 515.9958720330237}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:39.299Z',
#   'batchId': 16,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 515.7297576070139,
#   'processedRowsPerSecond': 507.8720162519045,
#   'durationMs': {'addBatch': 1477,
#    'getBatch': 6,
#    'getOffset': 9,
#    'queryPlanning': 3,
#    'triggerExecution': 1969,
#    'walCommit': 229},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 63454}},
#     'endOffset': {'fa-eh': {'0': 64454}},
#     'latestOffset': {'fa-eh': {'0': 64454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 515.7297576070139,
#     'processedRowsPerSecond': 507.8720162519045}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:41.269Z',
#   'batchId': 17,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 507.61421319796955,
#   'processedRowsPerSecond': 512.0327700972862,
#   'durationMs': {'addBatch': 1496,
#    'getBatch': 6,
#    'getOffset': 9,
#    'queryPlanning': 3,
#    'triggerExecution': 1953,
#    'walCommit': 210},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 64454}},
#     'endOffset': {'fa-eh': {'0': 65454}},
#     'latestOffset': {'fa-eh': {'0': 65454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 507.61421319796955,
#     'processedRowsPerSecond': 512.0327700972862}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:43.223Z',
#   'batchId': 18,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 511.77072671443193,
#   'processedRowsPerSecond': 512.5576627370579,
#   'durationMs': {'addBatch': 1496,
#    'getBatch': 7,
#    'getOffset': 11,
#    'queryPlanning': 5,
#    'triggerExecution': 1951,
#    'walCommit': 207},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 65454}},
#     'endOffset': {'fa-eh': {'0': 66454}},
#     'latestOffset': {'fa-eh': {'0': 66454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 511.77072671443193,
#     'processedRowsPerSecond': 512.5576627370579}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:45.174Z',
#   'batchId': 19,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 512.5576627370579,
#   'processedRowsPerSecond': 515.7297576070139,
#   'durationMs': {'addBatch': 1447,
#    'getBatch': 6,
#    'getOffset': 9,
#    'queryPlanning': 3,
#    'triggerExecution': 1939,
#    'walCommit': 240},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 66454}},
#     'endOffset': {'fa-eh': {'0': 67454}},
#     'latestOffset': {'fa-eh': {'0': 67454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 512.5576627370579,
#     'processedRowsPerSecond': 515.7297576070139}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:47.113Z',
#   'batchId': 20,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 515.7297576070139,
#   'processedRowsPerSecond': 481.92771084337346,
#   'durationMs': {'addBatch': 1560,
#    'getBatch': 6,
#    'getOffset': 10,
#    'queryPlanning': 4,
#    'triggerExecution': 2075,
#    'walCommit': 260},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 67454}},
#     'endOffset': {'fa-eh': {'0': 68454}},
#     'latestOffset': {'fa-eh': {'0': 68454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 515.7297576070139,
#     'processedRowsPerSecond': 481.92771084337346}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}},
#  {'id': '39acb6f8-b3ce-4897-ad74-3cb1d917e1ba',
#   'runId': '64db24ff-abe0-471e-973e-753e79cb0304',
#   'name': 'BrzTrafficStream',
#   'timestamp': '2024-02-07T18:51:49.189Z',
#   'batchId': 21,
#   'numInputRows': 1000,
#   'inputRowsPerSecond': 481.6955684007707,
#   'processedRowsPerSecond': 496.7709885742673,
#   'durationMs': {'addBatch': 1555,
#    'getBatch': 6,
#    'getOffset': 9,
#    'queryPlanning': 3,
#    'triggerExecution': 2013,
#    'walCommit': 211},
#   'stateOperators': [],
#   'sources': [{'description': 'org.apache.spark.sql.eventhubs.EventHubsSource@6ca0f4b8',
#     'startOffset': {'fa-eh': {'0': 68454}},
#     'endOffset': {'fa-eh': {'0': 69454}},
#     'latestOffset': {'fa-eh': {'0': 69454}},
#     'numInputRows': 1000,
#     'inputRowsPerSecond': 481.6955684007707,
#     'processedRowsPerSecond': 496.7709885742673}],
#   'sink': {'description': 'DeltaSink[Tables/CarTraffic_Raw]',
#    'numOutputRows': -1}}]

# %%
# %%sql
# select count(*) from CarTraffic_Raw
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 63, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# select * from CarTraffic_Raw
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 64, Finished, Available)
# <Spark SQL result set with 1000 rows and 10 fields>

# %% [markdown]
# ### **Streaming transformations**

# %% [markdown]
# **Parsing JSON payload, Applying filter transformation and writing to another table**

# %%
events_schema = StructType([
    StructField("EntryTime", TimestampType(), True),
    StructField("CarModel", StructType([
        StructField("Make", StringType(), True),
        StructField("Model", StringType(), True),
        StructField("VehicleType", IntegerType(), True),
        StructField("VehicleWeight", IntegerType(), True)
    ]), True),
    StructField("State", StringType(), True),
    StructField("TollAmount", IntegerType(), True),
    StructField("Tag", IntegerType(), True),
    StructField("TollId", IntegerType(), True),
    StructField("LicensePlate", StringType(), True),
    StructField("EventProcessedUtcTime", TimestampType(), True),
    StructField("PartitionId", IntegerType(), True),
    StructField("EventEnqueuedUtcTime", TimestampType(), True)
])
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 65, Finished, Available)

# %%
# mssparkutils.fs.rm (checkpointFolder,True)
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 53, Finished, Available)
# True

# %%
tableName='CarTraffic_Silver'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName

strmHandleSlv = spark.readStream\
.table("CarTraffic_Raw")\
.withColumn("eventsParsed",f.from_json(f.col('bodyAsString'),events_schema))\
.select('eventsParsed.*')\
.select('*','CarModel.*')\
.filter("State='TX' or State='NJ'")\
.drop('CarModel')\
.writeStream\
.queryName('SlvTrafficStream')\
.outputMode("append")\
.format("delta")\
.option("path", deltaTablePath)\
.option("checkpointLocation", checkpointFolder).start()
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 70, Finished, Available)

# %%
# print (f'Is the stream active?:{strmHandleSlv.isActive}',f', Stream status:{strmHandleSlv.status}')
# strmHandleSlv.stop()
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 69, Finished, Available)

# %%
# %%sql
# select * from CarTraffic_Silver
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 71, Finished, Available)
# <Spark SQL result set with 1000 rows and 13 fields>

# %% [markdown]
# ### **Aggregations**

# %% [markdown]
# **Simple aggregations,Notice the usage of 'complete' write mode**

# %%
tableName='CarTraffic_Gold'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName

strmHandleGld = spark.readStream\
.table("CarTraffic_Silver")\
.groupBy('Make')\
.agg(f.count('Model').alias('CarCount'))\
.writeStream\
.queryName('GldTrafficStream')\
.outputMode("complete")\
.format("delta")\
.option("path", deltaTablePath)\
.option("checkpointLocation", checkpointFolder).start()
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 72, Finished, Available)

# %%
# %%sql
# select * from CarTraffic_Gold
# Out:
# StatementMeta(, aea86997-8120-46ab-be89-c04b5e1a433d, 73, Finished, Available)
# <Spark SQL result set with 5 rows and 2 fields>

# %% [markdown]
# **Using Window functions**

# %%
from notebookutils import mssparkutils
mssparkutils.fs.rm (checkpointFolder,True)

# %%
from pyspark.sql.functions import *
tableName='CarTraffic_Gold2'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName

strmHandleGld2 = spark.readStream\
.table("CarTraffic_Silver")\
.groupBy("Make",window('EntryTime', "6 seconds", "3 seconds"))\
.agg(count('Model').alias('CarCount'))\
.writeStream\
.queryName('GldTrafficStream2')\
.outputMode("complete")\
.format("delta")\
.option("path", deltaTablePath)\
.option("checkpointLocation", checkpointFolder).start()
# Out:
# StatementMeta(, ab0772f9-3dfc-43ba-9d8b-45b1ee9d5a35, 3, Finished, Available)

# %%
# strmHandleGld2.stop()
# Out:
# StatementMeta(, 1de2e52b-90a4-4973-aa61-510d11bc639c, 98, Finished, Available)

# %%
# %%sql
# select Make,window.start,window.end,CarCount from CarTraffic_Gold2 order by Make,start
# Out:
# StatementMeta(, ab0772f9-3dfc-43ba-9d8b-45b1ee9d5a35, 4, Finished, Available)
# <Spark SQL result set with 22 rows and 4 fields>

# %% [markdown]
# **Aggregations with watermarking**

# %%
from pyspark.sql.functions import *
tableName='CarTraffic_Gold3'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName

strmHandleGld3 = spark.readStream\
.table("CarTraffic_Silver")\
.withWatermark("EntryTime", "2 seconds") \
.groupBy("Make",window('EntryTime', "6 seconds", "3 seconds"))\
.agg(count('Model').alias('CarCount'))\
.writeStream\
.queryName('GldTrafficStream3')\
.outputMode("complete")\
.format("delta")\
.option("path", deltaTablePath)\
.option("checkpointLocation", checkpointFolder).start()
# Out:
# StatementMeta(, 1de2e52b-90a4-4973-aa61-510d11bc639c, 108, Finished, Available)

# %%
# %%sql
# select Make,window.start,window.end,CarCount from CarTraffic_Gold3 order by Make,start
# Out:
# StatementMeta(, 1de2e52b-90a4-4973-aa61-510d11bc639c, 110, Finished, Available)
# <Spark SQL result set with 22 rows and 4 fields>

# %%
# strmHandle=query.start()
strmHandleGld3.stop()
# Out:
# StatementMeta(, 8de4c5a6-9fac-411c-8fb6-19f4383a8a66, 12, Finished, Available)

# %% [markdown]
# ### **JOINS**

# %%
from notebookutils import mssparkutils
mssparkutils.fs.rm ('Files/Checkpoints/CarTraffic_Silver_Joined',True)
# Out:
# StatementMeta(, , , Waiting, )
# True

# %%
tableName='CarTraffic_Silver_Joined'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName

df1 = spark.readStream.table("CarTraffic_Silver").alias('ct1')
df2 = spark.readStream.table("CarTraffic_Silver").withWatermark("EntryTime", "3 seconds").alias('ct2') 
CT_Joined_handle=df1\
.join(df2,f.expr("""ct1.LicensePlate=ct2.LicensePlate
   AND ct1.EntryTime<= ct2.EntryTime + interval 1 seconds"""))\
.selectExpr('ct1.TollId as TollId1','ct2.TollId as TollId2','ct1.Make','ct1.TollAmount')\
.writeStream\
.queryName(tableName+"-Stream")\
.outputMode("append")\
.format("delta")\
.option("path", deltaTablePath)\
.option("checkpointLocation", checkpointFolder).start()
# Out:
# StatementMeta(, bf5d4d9e-1048-497a-a6f0-a204282114ca, 11, Finished, Available)

# %%
# CT_Joined_handle.status
# CT_Joined_handle.stop()
# Out:
# StatementMeta(, bf5d4d9e-1048-497a-a6f0-a204282114ca, 12, Finished, Available)

# %%
# %%sql
# select * from CarTraffic_Silver_Joined
# Out:
# StatementMeta(, , , Waiting, )
# <Spark SQL result set with 1000 rows and 4 fields>

# %% [markdown]
# ### **Exploring Trigger options**

# %%
from notebookutils import mssparkutils
# mssparkutils.fs.rm ('Files/Checkpoints/CarTraffic_Silver2',True)
# mssparkutils.fs.rm ('Files/Checkpoints/CarTraffic_Silver3',True)
# mssparkutils.fs.rm ('Files/Checkpoints/CarTraffic_Pivoted4',True)

# %%
dfStrm = spark.readStream.table("CarTraffic_Silver")
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 9, Finished, Available)

# %% [markdown]
# **Fixed time intervals**

# %%
tableName='CarTraffic_Silver5'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName

strmHandle2 = dfStrm.withColumn('ProcessingTime',f.current_timestamp())\
.writeStream\
.queryName('CarTraffic_Silver2')\
.outputMode("append")\
.trigger(processingTime="10 second")\
.format("delta")\
.option("path", deltaTablePath)\
.option("checkpointLocation", checkpointFolder).start()
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 12, Finished, Available)

# %%
# %%sql
# select ProcessingTime,count(*) as RowCnt from CarTraffic_Silver5 group by ProcessingTime order by ProcessingTime
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 15, Finished, Available)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# **Optional: blocking further execution until streaming completes**

# %%
strmHandle2.awaitTermination()
# Out:
# StatementMeta(, cef74fa2-fd7f-43d4-9701-1dbacfbaa8db, 75, Finished, Cancelled)

# %% [markdown]
# **Run once and stop**

# %%
tableName='CarTraffic_Silver3'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName

strmHandle3 = dfStrm.writeStream\
.queryName('runOnce')\
.outputMode("append")\
.trigger(availableNow=True)\
.format("delta")\
.option("path", deltaTablePath)\
.option("checkpointLocation", "Files/Checkpoints/"+tableName).start()
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 18, Finished, Available)

# %%
print (f'Is the stream active?:{strmHandle3.isActive}',f', Stream status:{strmHandle3.status}')
# strmHandle3.stop()
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 19, Finished, Available)
# Is the stream active?:False , Stream status:{'message': 'Stopped', 'isDataAvailable': False, 'isTriggerActive': False}

# %% [markdown]
# **Using ForeachBatch**

# %%
def pivotEachBatch(df,batch_id):
   df.groupBy('State').pivot('Make').sum('TollAmount')\
   .withColumn('ProcessedTime',current_timestamp())\
   .write.format('delta').mode('append')\
   .saveAsTable('CarTraffic_Pivoted4')
   pass
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 20, Finished, Available)

# %%
tableName='CarTraffic_Pivoted4'
deltaTablePath = "Tables/" + tableName
checkpointFolder="Files/Checkpoints/"+tableName
strmHandle4 = dfStrm.writeStream\
.trigger(processingTime='1 seconds')\
.queryName('PivotingStrm')\
.option("checkpointLocation", "Files/Checkpoints/"+tableName)\
.foreachBatch(pivotEachBatch).start()
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 21, Finished, Available)

# %%
# %%sql
# select * from CarTraffic_Pivoted4
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 22, Finished, Available)
# <Spark SQL result set with 3 rows and 7 fields>

# %% [markdown]
# **Stop all active streams**

# %%
active_streams = spark.streams.active

for stream in active_streams:
    print(stream.name)
    stream.stop()
# Out:
# StatementMeta(, 665538dc-c0b2-4654-816b-fcb45f6b2bc0, 23, Finished, Available)
# CarTraffic_Silver2
